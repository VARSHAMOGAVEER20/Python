# %%
#New set 
A={1,2,3,5,6,7,8,9}
print(A)

#add
A.add(4)

#remove
A.remove(2)

#discard
A.discard(10)

#pop
A.pop(5)

#clear 
A.clear()

#union intersection and difference
B={1,2,3,4}
C={4,5,6,7}
print(B|C)
print(B&C)
print(B-C)
