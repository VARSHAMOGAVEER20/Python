# %%
my_tuple=("red","blue","white","black")
print(my_tuple[1])

#count
my_tuple=(1,2,3,1,2,4,5,6,6,5,4)
my_tuple.count[5]

#index
my_tuple=(1,2,3,1,2,4,5,6,6,5,4)
my_tuple.index(3)

#length
my_tuple=(1,2,3,1,2,4,5,6,6,5,4)
len(my_tuple)

#slice
my_tuple[1:3]
print(my_tuple)
# Out:
# blue
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 #count
#       5 my_tuple=(1,2,3,1,2,4,5,6,6,5,4)
# ----> 6 my_tuple.count[5]
#       8 #index
#       9 my_tuple=(1,2,3,1,2,4,5,6,6,5,4)
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
