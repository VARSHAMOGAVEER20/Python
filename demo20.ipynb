# %%
#sum
numbers=[10,20,30,40]
total=sum(numbers)
print(total)

#program to form a list
# (set() that converts the list/tuple into set. )
number=[1,2,3,3,4,5,5,4,3]
new_number=list(set(number))
print(new_number)

#program to convert a tuple into a list with modifying it
num=(1,2,3,4)
print("Original tuple",num)
num_list=list(num)
num_list.append(5)
print("Modified list",num_list)
num1=tuple(num_list)
print(num1)
