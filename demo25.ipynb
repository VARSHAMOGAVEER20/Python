# %%
class car:
    brand="Toyata"
    color="Red"
    def start(self):
        print("Car started")
        my_car=car()
        print("Brand",my_car.brand)
        print("color",my_car.color)
        my_car.start()
