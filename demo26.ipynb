# %%
#Constructor
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        s1=Student("Varsha",21)
        print("Name",s1.name)
        print("Age",s1.age)

#Parameterized constuctor
class person:
    def __init__(self,name,city):
        self.name=name
        self.city=city
        def show(self):
            p1=person()
            print("My name is {self.name} and I live in {self.city}")
            p1.person("Varsha","Banglore")
            p1.show()
